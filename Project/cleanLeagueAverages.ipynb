# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data gathered from https://www.basketball-reference.com/leagues/NBA_stats_per_game.html

# %%
raw_df = pd.read_csv('./raw/LeagueAverages.csv', skiprows=1)
raw_df.head()
# Out:
#    Rk   Season   Lg   Age   Ht     Wt     G     MP    FG   FGA  ...    PTS  \
# 0   1  2022-23  NBA  26.2  6-7  217.0   325  242.0  41.3  88.1  ...  113.0
# 1   2  2021-22  NBA  26.1  6-6  215.0  1230  241.4  40.6  88.1  ...  110.6
# 2   3  2020-21  NBA  26.1  6-6  217.0  1080  241.4  41.2  88.4  ...  112.1
# 3   4  2019-20  NBA  26.1  6-6  218.0  1059  241.8  40.9  88.8  ...  111.8
# 4   5  2018-19  NBA  26.3  6-6  219.0  1230  241.6  41.1  89.2  ...  111.2
#
#      FG%    3P%    FT%   Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# 0  0.469  0.356  0.782   99.3  0.538  13.1  24.2   0.207  112.8
# 1  0.461  0.354  0.775   98.2  0.532  12.3  23.2   0.192  112.0
# 2  0.466  0.367  0.778   99.2  0.538  12.4  22.2   0.192  112.3
# 3  0.460  0.358  0.773  100.3  0.529  12.8  22.5   0.201  110.6
# 4  0.461  0.355  0.766  100.0  0.524  12.4  22.9   0.198  110.4
#
# [5 rows x 32 columns]

# %%
df = raw_df.drop(columns = ['Rk', 'Lg'])
for i in range(df.shape[0]):
    df["Season"].values[i] = df["Season"].iloc[i].split("-")[0][:2] + df["Season"].iloc[i].split("-")[1]
#     df["Ht"].values[i] = int(df["Ht"].iloc[i].split("-")[0]) + df["Season"].iloc[i].split("-")[1]
df["Season"] = pd.to_numeric(df["Season"])
df.loc[df['Season'] == 1900, 'Season'] = 2000

# %%
df[df['Season']>=1985].to_csv('./modified/cleaned_LeagueAverages.csv', index=False)
