# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./modified/compare_salaryZscores.csv').drop(
    columns = ['salary_cap', 'salary', 'raptor_total', 'poss', 
               'log_scaled_salary_zscore', 'fixed_raptor_zscore'])

# %%
df.sort_values('Blocks', ascending=False)
# Out:
#              player_name  player_id  season team    mp  scaled_salary  \
# 16182     Walter Tavares  tavarwa01    2017  CLE    24       0.000055
# 4874          Mark Eaton  eatonma01    1985  UTA  2813       0.036944
# 17359    Rasheed Wallace  wallara01    2004  ATL    42            NaN
# 1760          Manute Bol    bolma01    1986  WAS  2090       0.032483
# 12675    Hakeem Olajuwon  olajuha01    1990  HOU  3124       0.255050
# ...                  ...        ...     ...  ...   ...            ...
# 15868  DeShawn Stevenson  stevede01    2010  DAL   267       0.067364
# 11626   Dirk Minniefield  minnidi01    1986  CLE  1131       0.017718
# 11617       Harold Miner  minerha01    1996  CLE   136       0.075348
# 2371       Shannon Brown  brownsh01    2015  MIA    89            NaN
# 8421          Mike James  jamesmi01    2009  NOP    74            NaN
#
#        2022 sal_cap Position  Age  # of games  Minutes  Rebounds  Assists  \
# ...

# %%
df[df['player_id'] == 'jordade01']
# Out:
#          player_name  player_id  season team    mp  scaled_salary  \
# 9110  DeAndre Jordan  jordade01    2009  LAC   771       0.009373
# 9111  DeAndre Jordan  jordade01    2010  LAC  1137       0.012763
# 9112  DeAndre Jordan  jordade01    2011  LAC  2047       0.014720
# 9113  DeAndre Jordan  jordade01    2012  LAC  1798       0.173651
# 9114  DeAndre Jordan  jordade01    2013  LAC  2010       0.181465
# 9115  DeAndre Jordan  jordade01    2014  LAC  2870       0.187231
# 9116  DeAndre Jordan  jordade01    2015  LAC  2820       0.181402
# 9117  DeAndre Jordan  jordade01    2016  LAC  2598       0.278571
# 9118  DeAndre Jordan  jordade01    2017  LAC  2570       0.224825
# 9119  DeAndre Jordan  jordade01    2018  LAC  2424       0.228496
# 9120  DeAndre Jordan  jordade01    2019  DAL  1554            NaN
# 9121  DeAndre Jordan  jordade01    2019  NYK   493       0.224771
# 9122  DeAndre Jordan  jordade01    2020  BKN  1234       0.090541
# ...

# %%
s = []
for i in range(18765):
    s.append('*'in df['player_name'])

# %%
sum(s)
# Out:
# 0
